# %% [markdown]
# # Natural Language Processing with Disaster Tweets

# %% [markdown]
# ## 1 Imports

# %%
# !/anaconda/envs/azureml_py38_PT_TF/bin/python -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: absl-py==2.1.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (2.1.0)
# Requirement already satisfied: astunparse==1.6.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (1.6.3)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (4.12.3)
# Requirement already satisfied: cachetools==5.3.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 5)) (5.3.3)
# Requirement already satisfied: certifi==2024.6.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (2024.6.2)
# Requirement already satisfied: charset-normalizer==3.3.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (8.1.7)
# Requirement already satisfied: contourpy==1.1.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (1.1.1)
# Requirement already satisfied: cycler==0.12.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: flatbuffers==24.3.25 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 11)) (24.3.25)
# Requirement already satisfied: fonttools==4.53.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 12)) (4.53.0)
# Requirement already satisfied: gast==0.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 13)) (0.4.0)
# Requirement already satisfied: google-auth==2.30.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 14)) (2.30.0)
# Requirement already satisfied: google-auth-oauthlib==1.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 15)) (1.0.0)
# Requirement already satisfied: google-pasta==0.2.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 16)) (0.2.0)
# Requirement already satisfied: grpcio==1.64.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 17)) (1.64.1)
# Requirement already satisfied: h5py==3.11.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 18)) (3.11.0)
# Requirement already satisfied: idna==3.7 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 19)) (3.7)
# Requirement already satisfied: importlib-metadata==7.1.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 20)) (7.1.0)
# Requirement already satisfied: importlib-resources==6.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 21)) (6.4.0)
# Requirement already satisfied: joblib==1.4.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 22)) (1.4.2)
# Requirement already satisfied: keras==2.13.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 23)) (2.13.1)
# Requirement already satisfied: kiwisolver==1.4.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 24)) (1.4.5)
# Requirement already satisfied: libclang==18.1.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 25)) (18.1.1)
# Requirement already satisfied: markdown==3.6 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 26)) (3.6)
# Requirement already satisfied: markupsafe==2.1.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 27)) (2.1.5)
# Requirement already satisfied: matplotlib==3.7.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 28)) (3.7.5)
# Requirement already satisfied: nltk==3.8.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 29)) (3.8.1)
# Requirement already satisfied: numpy==1.24.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 30)) (1.24.3)
# Requirement already satisfied: oauthlib==3.2.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 31)) (3.2.2)
# Requirement already satisfied: opt-einsum==3.3.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 32)) (3.3.0)
# Requirement already satisfied: packaging==24.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 33)) (24.1)
# Requirement already satisfied: pandas==2.0.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 34)) (2.0.3)
# Requirement already satisfied: pillow==10.3.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 35)) (10.3.0)
# Requirement already satisfied: protobuf==4.25.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 36)) (4.25.3)
# Requirement already satisfied: pyasn1==0.6.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 37)) (0.6.0)
# Requirement already satisfied: pyasn1-modules==0.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 38)) (0.4.0)
# Requirement already satisfied: pyparsing==3.1.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 39)) (3.1.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 40)) (2.9.0.post0)
# Requirement already satisfied: pytz==2024.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 41)) (2024.1)
# Requirement already satisfied: regex==2024.5.15 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 42)) (2024.5.15)
# Requirement already satisfied: requests==2.32.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 43)) (2.32.3)
# Requirement already satisfied: requests-oauthlib==2.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 44)) (2.0.0)
# Requirement already satisfied: rsa==4.9 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 45)) (4.9)
# Requirement already satisfied: scikit-learn==1.3.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 46)) (1.3.2)
# Requirement already satisfied: scipy==1.10.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 47)) (1.10.1)
# Requirement already satisfied: seaborn==0.13.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 48)) (0.13.2)
# Requirement already satisfied: setuptools==70.0.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 49)) (70.0.0)
# Requirement already satisfied: six==1.16.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 50)) (1.16.0)
# Requirement already satisfied: soupsieve==2.5 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 51)) (2.5)
# Requirement already satisfied: tensorboard==2.13.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 52)) (2.13.0)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 53)) (0.7.2)
# Requirement already satisfied: tensorflow==2.13.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 54)) (2.13.1)
# Requirement already satisfied: tensorflow-estimator==2.13.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 55)) (2.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.34.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 56)) (0.34.0)
# Requirement already satisfied: termcolor==2.4.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 57)) (2.4.0)
# Requirement already satisfied: threadpoolctl==3.5.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 58)) (3.5.0)
# Requirement already satisfied: tqdm==4.66.4 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 59)) (4.66.4)
# Requirement already satisfied: typing-extensions==4.5.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 60)) (4.5.0)
# Requirement already satisfied: tzdata==2024.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 61)) (2024.1)
# Requirement already satisfied: urllib3==2.2.1 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 62)) (2.2.1)
# Requirement already satisfied: werkzeug==3.0.3 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 63)) (3.0.3)
# Requirement already satisfied: wheel==0.43.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 64)) (0.43.0)
# Requirement already satisfied: wrapt==1.16.0 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 65)) (1.16.0)
# Requirement already satisfied: zipp==3.19.2 in /anaconda/envs/azureml_py38_PT_TF/lib/python3.8/site-packages (from -r requirements.txt (line 66)) (3.19.2)

# %%
# %matplotlib inline
import numpy as np
from numpy import argmax
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

from bs4 import BeautifulSoup
import re

from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM
from keras.callbacks import EarlyStopping

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import nltk
import joblib
# Out:
# 2024-06-12 11:23:52.588865: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-12 11:23:52.750801: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-06-12 11:23:52.755595: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2024-06-12 11:23:52.755625: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2024-06-12 11:23:53.659124: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-06-12 11:23:53.659250: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-06-12 11:23:53.659260: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/azureuser/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## 2 Data exploration / plots

# %% [markdown]
# Reading in train.csv & test.csv.

# %%
df_train = pd.read_csv('CSV/train.csv')
df_test = pd.read_csv('CSV/test.csv')

# %%
X_train = df_train['text']
y_train = df_train['target']

X_train, y_train = shuffle(X_train, y_train, random_state=42)
id = df_test['id']

# %%
X_test = df_test['text']

# %% [markdown]
# ## 3 Text-preprocessing

# %%
def text_preprocessing(text, language, minWordSize):

    text_no_html = BeautifulSoup(text, "html.parser").get_text()

    text_no_url = re.sub(r'http\S+', ' ', text_no_html)

    text_no_at = ''
    for word in text_no_url.split():
        if not word.startswith('@'):  
            text_no_at = text_no_at + word + ' '
            
    text_no_RT = ''
    for word in text_no_at.split():
        if not word.startswith('RT'):  
            text_no_RT = text_no_RT + word + ' '         

    text_alpha_chars = re.sub("[^a-zA-Z']", " ", str(text_no_RT))

    text_lower = text_alpha_chars.lower()

    stops = set(stopwords.words(language)) 
    text_no_stop_words = ' '
    
    whitelist = ["n't", "not", "no"]
    for word in text_lower.split():
        if word not in stops or word in whitelist:  
            text_no_stop_words = text_no_stop_words + word + ' '

    text_stemmer = ' '
    stemmer = SnowballStemmer(language)
    for w in text_no_stop_words.split():
        text_stemmer = text_stemmer + stemmer.stem(w) + ' '

    text_no_short_words = ' '
    for w in text_stemmer.split(): 
        if len(w) >=minWordSize:
            text_no_short_words = text_no_short_words + w + ' '
 

    return text_no_short_words

# %%
language = 'english'
minWordLength = 2
text_prep = np.empty

for i in range(X_train.shape[0]):
    X_train.iloc[i] = text_preprocessing(X_train.iloc[i], language, minWordLength)
    
    
for i in range(X_test.shape[0]):
    X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# Out:
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/3639917976.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text_no_html = BeautifulSoup(text, "html.parser").get_text()
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)
# /tmp/ipykernel_20385/342931162.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test.iloc[i] = text_preprocessing(X_test.iloc[i], language, minWordLength)

# %%
X_train
# Out:
# 2644                  new weapon caus un imagin destruct
# 2227     ing thing gishwh got soak delug go pad tampon...
# 5448       dt col polic catch pickpocket liverpool stree
# 132      aftershock back school kick great want thank ...
# 6845     respons trauma children addict develop defens...
#                               ...
# 5226                 mani obliter server alway like play
# 5390     panic attack bc enough money drug alcohol wan...
# 860      omron hem automat blood pressur monitor stand...
# 7603     offici say quarantin place alabama home possi...
# 7270     move england five year ago today whirlwind time
# Name: text, Length: 7613, dtype: object

# %%
X_train_clean = X_train.copy()
X_test_clean = X_test.copy()

# %%
count_vect = CountVectorizer()
X_train_bag_of_words = count_vect.fit_transform(X_train)
X_test_bag_of_words = count_vect.transform(X_test)


tfidf_transformer = TfidfTransformer()
tf_transformer = TfidfTransformer(use_idf=True).fit(X_train_bag_of_words)
X_train_tf = tf_transformer.transform(X_train_bag_of_words)
X_test_tf = tf_transformer.transform(X_test_bag_of_words)

# %% [markdown]
# ## 4 Building Models

# %% [markdown]
# ### 4.1 LSTM Model

# %%
model = LogisticRegression()
paramaters = [{'C' : [0.001, 0.01, 0.1, 1, 10, 100, 1000,10000, 100000]}                                       
             ]
                            
random_search = RandomizedSearchCV(estimator = model,  n_iter = 9, 
                           param_distributions = paramaters,
                           scoring = 'accuracy',
                           cv = 4,
                           n_jobs = -1)

random_search = random_search.fit(X_train_tf, y_train)

best_accuracy = random_search.best_score_ 
best_parameters = random_search.best_params_  

print('Best accuracy : ', random_search.best_score_)
print('Best parameters :', random_search.best_params_  )
# Out:
# Best accuracy :  0.8017863214650022
# Best parameters : {'C': 1}

# %%
model = LogisticRegression()
paramaters = [{'C' : [0.9,0.91,0.92,0.93,0.94,0.95,0.96,0.97,0.98,0.99,1,1.01,1.02,1.03,1.04,1.05,1.06,1.07,1.08,1.09,1.1]}                                       
             ]
                            
grid_search = GridSearchCV(estimator = model, 
                           param_grid = paramaters,
                           scoring = 'accuracy',
                           cv = 4,
                           n_jobs = -1)

grid_search = grid_search.fit(X_train_tf, y_train)

best_accuracy = grid_search.best_score_ 
best_parameters = grid_search.best_params_  

print('Best accuracy : ', grid_search.best_score_)
print('Best parameters :', grid_search.best_params_  )
# Out:
# Best accuracy :  0.8021802980256738
# Best parameters : {'C': 1.02}

# %%
max_fatures = 2000

tokenizer = Tokenizer(oov_token= True, num_words=max_fatures, split=' ')
tokenizer.fit_on_texts(X_train_clean)
X_train_tok = tokenizer.texts_to_sequences(X_train_clean)
X_test_tok = tokenizer.texts_to_sequences(X_test_clean)

X_train_tok = pad_sequences(X_train_tok)
X_test_tok = pad_sequences(X_test_tok,maxlen=X_train_tok.shape[1])

# %%
X_train_tok.shape
# Out:
# (7613, 23)

# %%
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_train_class = to_categorical(y_train)

# %%
early_stopping =  EarlyStopping(patience=8,  restore_best_weights=True)

model = Sequential()
model.add(Embedding(input_dim=2000,output_dim =128, input_length = X_train_tok.shape[1]))
model.add(LSTM(100, return_sequences=True, dropout=0.2, recurrent_dropout=0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(2,activation='softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])

history = model.fit(X_train_tok, y_train_class, epochs = 100, batch_size=16, verbose = 2, validation_split= 0.2,
                   callbacks=[early_stopping])
# Out:
# 2024-06-12 11:24:17.261031: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:267] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-06-12 11:24:17.261098: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (mlopsprojectcompute): /proc/driver/nvidia/version does not exist
# 2024-06-12 11:24:17.262079: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/100
# 381/381 - 28s - loss: 0.5054 - accuracy: 0.7542 - val_loss: 0.4750 - val_accuracy: 0.7971 - 28s/epoch - 74ms/step
# Epoch 2/100
# 381/381 - 24s - loss: 0.3790 - accuracy: 0.8386 - val_loss: 0.4988 - val_accuracy: 0.7938 - 24s/epoch - 63ms/step
# Epoch 3/100
# 381/381 - 25s - loss: 0.3408 - accuracy: 0.8565 - val_loss: 0.4710 - val_accuracy: 0.7958 - 25s/epoch - 66ms/step
# Epoch 4/100
# 381/381 - 24s - loss: 0.2946 - accuracy: 0.8800 - val_loss: 0.5288 - val_accuracy: 0.7971 - 24s/epoch - 63ms/step
# Epoch 5/100
# 381/381 - 24s - loss: 0.2406 - accuracy: 0.9007 - val_loss: 0.6277 - val_accuracy: 0.7728 - 24s/epoch - 64ms/step
# Epoch 6/100
# 381/381 - 24s - loss: 0.1988 - accuracy: 0.9204 - val_loss: 0.7717 - val_accuracy: 0.7859 - 24s/epoch - 63ms/step
# Epoch 7/100
# 381/381 - 23s - loss: 0.1688 - accuracy: 0.9266 - val_loss: 0.8502 - val_accuracy: 0.7623 - 23s/epoch - 61ms/step
# Epoch 8/100
# 381/381 - 23s - loss: 0.1382 - accuracy: 0.9396 - val_loss: 1.1249 - val_accuracy: 0.7669 - 23s/epoch - 62ms/step
# Epoch 9/100
# 381/381 - 25s - loss: 0.1217 - accuracy: 0.9479 - val_loss: 1.1541 - val_accuracy: 0.7617 - 25s/epoch - 66ms/step
# Epoch 10/100

# %%
y_pred = model.predict(X_train_tok[int(len(X_train_tok)*0.8):])
y_pred = argmax(y_pred, axis=1)

y_true = argmax(y_train_class[int(len(y_train_class)*0.8):], axis=1)

print(f'Accuracy: {accuracy_score(y_true, y_pred)}')
print(f'Precision: {precision_score(y_true, y_pred)}')
print(f'Recall: {recall_score(y_true, y_pred)}')
print(f'F1 score: {f1_score(y_true, y_pred)}')

# %%
predictions_test = grid_search.predict(X_test_tf)

# %%
le = preprocessing.LabelEncoder()
le.fit(predictions_test)
predictions_test = le.transform(predictions_test)
predictions_test

# %%
df = pd.DataFrame({
    'id': id,
    'target': predictions_test
})

df['target'] = encoder.inverse_transform(df['target'])

print(df)

# %%
df.to_csv('CSV/predictionsLSTM.csv', index=False)

# %%
# Save tokenizer
joblib.dump(tokenizer, 'tokenizer.pkl')

# Save model
model.save('disaster_tweet_lstm_model.h5')
